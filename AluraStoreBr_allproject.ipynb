# %% [markdown]
# <a href="https://colab.research.google.com/github/GabiRuffo/Challenge_AluraStore/blob/main/AluraStoreBr_allproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
def faturamento(loja):
    soma = loja['Preço'].sum()
    return soma

def faturamento(loja2):
    soma2 = loja2['Preço'].sum()
    return soma2

def faturamento(loja3):
    soma3 = loja3['Preço'].sum()
    return soma3

def faturamento(loja4):
    soma4 = loja4['Preço'].sum()
    return soma4

# %%
faturamento_total = faturamento(loja)
print(f'o faturamento total da loja 1 foi de R$ {faturamento_total}')
print('===' * 30)

faturamento_total2 = faturamento(loja2)
print(f'o faturamento total da loja 2 foi de R$ {faturamento_total2}')
print('===' * 30)

faturamento_total3 = faturamento(loja3)
print(f'o faturamento total da loja 3 foi de R$ {faturamento_total3}')
print('===' * 30)

faturamento_total4 = faturamento(loja4)
print(f'o faturamento total da loja 4 foi de R$ {faturamento_total4}')
print('===' * 30)
# Out:
# o faturamento total da loja 1 foi de R$ 1534509.12
# ...
# o faturamento total da loja 2 foi de R$ 1488459.06
# ...
# o faturamento total da loja 3 foi de R$ 1464025.03
# ...
# o faturamento total da loja 4 foi de R$ 1384497.58
# ...

# %%
#grafico de faturamento por loja.
import matplotlib.pyplot as plt

faturamento_lojas = {
    'Loja 1': loja['Preço'].sum(),
    'Loja 2': loja2['Preço'].sum(),
    'Loja 3': loja3['Preço'].sum(),
    'Loja 4': loja4['Preço'].sum()
}

cores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

plt.figure(figsize=(8, 5))
plt.bar(faturamento_lojas.keys(), faturamento_lojas.values(), color=cores)
plt.title('Faturamento por Loja')
plt.ylabel('Faturamento (R$)')
plt.xlabel('Lojas')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
contagem = loja["Categoria do Produto"].value_counts()
print(contagem)
print('===' * 30)
categoria_mais_vendida_valor = contagem.max()
categoria_menos_vendida_valor= contagem.min()

contagem2 = loja2["Categoria do Produto"].value_counts()
print(contagem2)
print('===' * 30)
categoria_mais_vendida_valor2 = contagem2.max()
categoria_menos_vendida_valor2= contagem2.min()

contagem3 = loja3["Categoria do Produto"].value_counts()
print(contagem3)
print('===' * 30)
categoria_mais_vendida_valor3 = contagem3.max()
categoria_menos_vendida_valor3= contagem3.min()

contagem4 = loja4["Categoria do Produto"].value_counts()
print(contagem4)
print('===' * 30)
categoria_mais_vendida_valor4 = contagem4.max()
categoria_menos_vendida_valor4= contagem4.min()
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
# ...
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
# ...
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64
# ...
# Categoria do Produto
# moveis                   480
# eletronicos              451
# ...

# %%
categoria_mais_vendida = contagem.idxmax()
categoria_menos_vendida = contagem.idxmin()

print(f' A categoria mais vendida foi {categoria_mais_vendida} com {categoria_mais_vendida_valor} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida} com {categoria_menos_vendida_valor} unidades vendidas.')
print('===' * 30)

categoria_mais_vendida2 = contagem2.idxmax()
categoria_menos_vendida2 = contagem2.idxmin()

print(f' A categoria mais vendida foi {categoria_mais_vendida2} com {categoria_mais_vendida_valor2} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida2} com {categoria_menos_vendida_valor2} unidades vendidas.')
print('===' * 30)

categoria_mais_vendida3 = contagem3.idxmax()
categoria_menos_vendida3 = contagem3.idxmin()

print(f' A categoria mais vendida foi {categoria_mais_vendida3} com {categoria_mais_vendida_valor3} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida3} com {categoria_menos_vendida_valor3} unidades vendidas.')
print('===' * 30)

categoria_mais_vendida4 = contagem4.idxmax()
categoria_menos_vendida4 = contagem4.idxmin()

print(f' A categoria mais vendida foi {categoria_mais_vendida4} com {categoria_mais_vendida_valor4} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida4} com {categoria_menos_vendida_valor4} unidades vendidas.')
print('===' * 30)
# Out:
#  A categoria mais vendida foi moveis com 465 unidades vendidas.
# A categoria menos vendida foi utilidades domesticas com 171 unidades vendidas.
# ...
#  A categoria mais vendida foi moveis com 442 unidades vendidas.
# A categoria menos vendida foi utilidades domesticas com 181 unidades vendidas.
# ...
#  A categoria mais vendida foi moveis com 499 unidades vendidas.
# A categoria menos vendida foi instrumentos musicais com 177 unidades vendidas.
# ...
#  A categoria mais vendida foi moveis com 480 unidades vendidas.
# A categoria menos vendida foi instrumentos musicais com 170 unidades vendidas.
# ...

# %%
# Quantidades das categorias mais e menos vendidas por loja
quantidades_mais = [categoria_mais_vendida_valor, categoria_mais_vendida_valor2, categoria_mais_vendida_valor3, categoria_mais_vendida_valor4]
quantidades_menos = [categoria_menos_vendida_valor, categoria_menos_vendida_valor2, categoria_menos_vendida_valor3, categoria_menos_vendida_valor4]

# Categorias mais e menos vendidas
categorias_mais_vendidas = [categoria_mais_vendida, categoria_mais_vendida2, categoria_mais_vendida3, categoria_mais_vendida4]
categorias_menos_vendidas = [categoria_menos_vendida, categoria_menos_vendida2, categoria_menos_vendida3, categoria_menos_vendida4]

# Lojas
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Criando o gráfico de linhas
plt.figure(figsize=(10, 6))

# Gráfico para o produto mais vendido por loja
plt.plot(lojas, quantidades_mais, marker='o', linestyle='-', color='purple', label='Produto Mais Vendido')

# Gráfico para o produto menos vendido por loja
plt.plot(lojas, quantidades_menos, marker='o', linestyle='-', color='yellow', label='Produto Menos Vendido')

# Título e rótulos
plt.title('Categorias mais e menos vendidas por loja', fontsize=14)
plt.xlabel('Lojas', fontsize=12)
plt.ylabel('Quantidade Vendida', fontsize=12)

# Anotando as quantidades nos gráficos
for i, v in enumerate(quantidades_mais):
    plt.text(i, v + 0.2, f'{categorias_mais_vendidas[i]}: {v}', ha='center', va='bottom', fontsize=9, color='black')

for i, v in enumerate(quantidades_menos):
    plt.text(i, v - 0.2, f'{categorias_menos_vendidas[i]}: {v}', ha='center', va='top', fontsize=9, color='black')

# Layout final
plt.tight_layout()
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliacao = display(loja['Avaliação da compra'].value_counts())
print('===' * 30)

avaliacao2 = display(loja2['Avaliação da compra'].value_counts())
print('===' * 30)

avaliacao3 = display(loja3['Avaliação da compra'].value_counts())
print('===' * 30)

avaliacao4 = display(loja4['Avaliação da compra'].value_counts())
print('===' * 30)
# Out:
# Avaliação da compra
# 5    1292
# 4     444
# 1     319
# 3     218
# 2      86
# Name: count, dtype: int64
# ...
# Avaliação da compra
# 5    1302
# 4     482
# 1     273
# 3     209
# 2      93
# Name: count, dtype: int64
# ...
# Avaliação da compra
# 5    1356
# 4     434
# 1     297
# 3     193
# 2      79
# Name: count, dtype: int64
# ...
# Avaliação da compra
# 5    1300
# 4     453
# 1     310
# 3     210
# 2      85
# Name: count, dtype: int64
# ...

# %%
media_avaliacao_loja = loja['Avaliação da compra'].sum()/len(loja['Avaliação da compra'])
print(f'A média de avaliação da loja 1 foi {media_avaliacao_loja:.2f}')
print('===' * 30)

media_avaliacao_loja2 = loja2['Avaliação da compra'].sum()/len(loja2['Avaliação da compra'])
print(f'A média de avaliação da loja 2 foi {media_avaliacao_loja2:.2f}')
print('===' * 30)

media_avaliacao_loja3 = loja3['Avaliação da compra'].sum()/len(loja3['Avaliação da compra'])
print(f'A média de avaliação da loja 3 foi {media_avaliacao_loja3:.2f}')
print('===' * 30)

media_avaliacao_loja4 = loja4['Avaliação da compra'].sum()/len(loja4['Avaliação da compra'])
print(f'A média de avaliação da loja 4 foi {media_avaliacao_loja4:.2f}')
print('===' * 30)
# Out:
# A média de avaliação da loja 1 foi 3.98
# ...
# A média de avaliação da loja 2 foi 4.04
# ...
# A média de avaliação da loja 3 foi 4.05
# ...
# A média de avaliação da loja 4 foi 4.00
# ...

# %%
media_avaliacao = [media_avaliacao_loja, media_avaliacao_loja2, media_avaliacao_loja3, media_avaliacao_loja4]
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

cores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

plt.figure(figsize=(10, 6))
plt.barh(lojas, media_avaliacao, color=cores, edgecolor='black')

plt.title('Média de Avaliação por Loja', fontsize=14)
plt.xlabel('Média de Avaliação', fontsize=12)
plt.ylabel('Lojas', fontsize=12)
plt.xlim(0, 10)

for i, v in enumerate(media_avaliacao):
    plt.text(v + 0.2, i, f'{v:.2f}', va='center', fontsize=10, color='black')

plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
contagem_produto = loja["Produto"].value_counts()
print(contagem_produto)
print('===' * 30)

contagem_produto2 = loja2["Produto"].value_counts()
print(contagem_produto2)
print('===' * 30)

contagem_produto3 = loja3["Produto"].value_counts()
print(contagem_produto3)
print('===' * 30)

contagem_produto4 = loja4["Produto"].value_counts()
print(contagem_produto4)
print('===' * 30)
# Out:
# Produto
# Micro-ondas                    60
# TV Led UHD 4K                  60
# Guarda roupas                  60
# Secadora de roupas             58
# Cômoda                         56
# Blocos de montar               56
# Bola de basquete               55
# Bicicleta                      54
# Copo térmico                   54
# Geladeira                      54
# Impressora                     54
# Bateria                        53
# Faqueiro                       52
# Carrinho controle remoto       52
# Modelagem preditiva            51
# Fone de ouvido                 50
# Xadrez de madeira              49
# Celular Plus X42               49
# Lava louças                    48
# Lavadora de roupas             47
# Guitarra                       47
# Violão                         46
# Sofá retrátil                  46
# Cadeira de escritório          46
# Fogão                          45
# Cama box                       44
# Kit banquetas                  44
# ...

# %%
produto_mais_vendido_valor = contagem_produto.max()
produto_menos_vendido_valor = contagem_produto.min()
produto_mais_vendido = contagem_produto[contagem_produto == produto_mais_vendido_valor]
produto_menos_vendido = contagem_produto[contagem_produto == produto_menos_vendido_valor]

print("📈 Produtos mais vendidos:")
for contagem_produto, qtd in produto_mais_vendido.items():
    print(f"Produto: {contagem_produto} - {qtd} unidades")
print("\n📉 Produtos menos vendidos:")
for contagem_produto, qtd in produto_menos_vendido.items():
    print(f"Produto: {contagem_produto} - {qtd} unidades")
print('===' * 30)

produto_mais_vendido_valor2 = contagem_produto2.max()
produto_menos_vendido_valor2= contagem_produto2.min()
produto_mais_vendido2 = contagem_produto2[contagem_produto2 == produto_mais_vendido_valor2]
produto_menos_vendido2 = contagem_produto2[contagem_produto2 == produto_menos_vendido_valor2]

print("📈 Produtos mais vendidos:")
for contagem_produto2, qtd in produto_mais_vendido2.items():
    print(f"Produto: {contagem_produto2} - {qtd} unidades")
print("\n📉 Produtos menos vendidos:")
for contagem_produto2, qtd in produto_menos_vendido2.items():
    print(f"Produto: {contagem_produto2} - {qtd} unidades")
print('===' * 30)

produto_mais_vendido_valor3 = contagem_produto3.max()
produto_menos_vendido_valor3= contagem_produto3.min()
produto_mais_vendido3 = contagem_produto3[contagem_produto3 == produto_mais_vendido_valor3]
produto_menos_vendido3 = contagem_produto3[contagem_produto3 == produto_menos_vendido_valor3]

print("📈 Produtos mais vendidos:")
for contagem_produto3, qtd in produto_mais_vendido3.items():
    print(f"Produto: {contagem_produto3} - {qtd} unidades")
print("\n📉 Produtos menos vendidos:")
for contagem_produto3, qtd in produto_menos_vendido3.items():
    print(f"Produto: {contagem_produto3} - {qtd} unidades")
print('===' * 30)

produto_mais_vendido_valor4 = contagem_produto4.max()
produto_menos_vendido_valor4= contagem_produto4.min()
produto_mais_vendido4 = contagem_produto4[contagem_produto4 == produto_mais_vendido_valor4]
produto_menos_vendido4 = contagem_produto4[contagem_produto4 == produto_menos_vendido_valor4]

print("📈 Produtos mais vendidos:")
for contagem_produto4, qtd in produto_mais_vendido4.items():
    print(f"Produto: {contagem_produto4} - {qtd} unidades")
print("\n📉 Produtos menos vendidos:")
for contagem_produto4, qtd in produto_menos_vendido4.items():
    print(f"Produto: {contagem_produto4} - {qtd} unidades")
print('===' * 30)
# Out:
# 📈 Produtos mais vendidos:
# Produto: Micro-ondas - 60 unidades
# Produto: TV Led UHD 4K - 60 unidades
# Produto: Guarda roupas - 60 unidades
#
# 📉 Produtos menos vendidos:
# Produto: Headset - 33 unidades
# Produto: Celular ABXY - 33 unidades
# ...
# 📈 Produtos mais vendidos:
# Produto: Iniciando em programação - 65 unidades
#
# 📉 Produtos menos vendidos:
# Produto: Jogo de tabuleiro - 32 unidades
# ...
# 📈 Produtos mais vendidos:
# Produto: Kit banquetas - 57 unidades
#
# 📉 Produtos menos vendidos:
# Produto: Blocos de montar - 35 unidades
# ...
# 📈 Produtos mais vendidos:
# Produto: Cama box - 62 unidades
#
# 📉 Produtos menos vendidos:
# Produto: Guitarra - 33 unidades
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
custo_medio_frete =loja['Frete'].sum()/len(loja['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete:.2f}.')
print('===' * 30)

custo_medio_frete2 =loja2['Frete'].sum()/len(loja2['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete2:.2f}.')
print('===' * 30)

custo_medio_frete3 =loja3['Frete'].sum()/len(loja3['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete3:.2f}.')
print('===' * 30)

custo_medio_frete4 =loja4['Frete'].sum()/len(loja4['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete4:.2f}.')
print('===' * 30)
# Out:
# O custo médio do frente  é de R$ 34.69.
# ...
# O custo médio do frente  é de R$ 33.62.
# ...
# O custo médio do frente  é de R$ 33.07.
# ...
# O custo médio do frente  é de R$ 31.28.
# ...

# %%
import matplotlib.pyplot as plt

frete_medio = {
    'Loja 1': loja['Frete'].mean(),
    'Loja 2': loja2['Frete'].mean(),
    'Loja 3': loja3['Frete'].mean(),
    'Loja 4': loja4['Frete'].mean()
}

plt.figure(figsize=(8, 8))
plt.pie(frete_medio.values(), labels=frete_medio.keys(), autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])

plt.title('Distribuição do Custo Médio de Frete por Loja')

plt.tight_layout()
plt.show()

# %%
#Analisando o valor total do faturamento mais o frete para melhor decisao:

receita_total_loja = loja['Preço'].sum() + loja['Frete'].sum()
receita_total_loja2 = loja2['Preço'].sum() + loja2['Frete'].sum()
receita_total_loja3 = loja3['Preço'].sum() + loja3['Frete'].sum()
receita_total_loja4 = loja4['Preço'].sum() + loja4['Frete'].sum()

print(f'🛒 Faturamento total da Loja 1 (vendas + frete): R$ {receita_total_loja:.2f}')
print(f'🛒 Faturamento total da Loja 2 (vendas + frete): R$ {receita_total_loja2:.2f}')
print(f'🛒 Faturamento total da Loja 3 (vendas + frete): R$ {receita_total_loja3:.2f}')
print(f'🛒 Faturamento total da Loja 4 (vendas + frete): R$ {receita_total_loja4:.2f}')
print('===' * 30)
# Out:
# 🛒 Faturamento total da Loja 1 (vendas + frete): R$ 1616347.09
# 🛒 Faturamento total da Loja 2 (vendas + frete): R$ 1567773.22
# 🛒 Faturamento total da Loja 3 (vendas + frete): R$ 1542047.69
# 🛒 Faturamento total da Loja 4 (vendas + frete): R$ 1458253.46
# ...

# %% [markdown]
# # **Relatório** Final:
#
# Analise comparativa da rede de lojas Alura Store:
#
# O objetivo desta análise é identificar, com base em dados históricos de vendas, a loja mais adequada para o Senhor João focar suas estratégias de comercialização. A partir da base de dados da Alura Store, foram avaliadas quatro lojas, considerando diferentes métricas importantes para o desempenho comercial: faturamento total, faturamento total incluindo o valor do frete, categorias de produtos mais e menos vendidas, produtos mais e menos vendidos, média das avaliações dos clientes e o custo médio com frete. A análise foi acompanhada por visualizações gráficas para facilitar a compreensão dos resultados.
#
# Durante o processo, foi identificado:
# *   Faturamento Total: Foi calculado o somatório dos valores de venda, demonstrando o quanto cada unidade arrecadou no total. E foi constatado que o resultado por loja foram:
#             Loja 1: R$ 1534509.12
#             Loja 2: R$ 1488459.06
#             Loja 3: R$ 1464025.03
#             Loja 4: R$ 1384497.58
# Assim definindo que a loja 1 teve maior retorno e a loja 4 o menor.
#
# *   Categorias Mais e Menos Vendidas: Foi verificado o desempenho das categorias de produtos vendidas por cada loja, destacando as preferências dos consumidores e os segmentos com menor rotatividade. Seus resultados foram:
#             Loja 1: Moveis foi a categoria mais vendida com 465 unidades e utilidades domesticas a menos vendida com 171 unidades.
#             Loja 2: Moveis foi a categoria mais vendida com 442 unidades e utilidades domesticas a menos vendida com 181 unidades.
#             Loja 3: Moveis foi a categoria mais vendida com 499 unidades e instrumentos musicais a menos vendida com 177 unidades.
#             Loja 4: Moveis foi a categoria mais vendida com 480 unidades e instrumentos musicais a menos vendida com 170 unidades.
# Assim definindo que Moveis foi unanime como a categoria mais vendida das lojas, porem tendo a Loja 3 como maior numero de vendas. Logo, o menor numero de vendas é da categoria Instrumentos musicais, tendo a Loja 4 com vendas inferiores.
#
# *   Avaliação Média dos Clientes: As notas atribuídas pelos consumidores foram analisadas individualmente por loja, permitindo observar o nível medio de satisfação com os serviços prestados. Resultando em:
#             Loja 1: Media de 3.98
#             Loja 2: Media de 4.04
#             Loja 3: Media de 4.05
#             Loja 4: Media de 4.00
# Foi observado que a Loja 1 teve pior desempenho em relacao a expectativa dos clientes, e tendo como contraste o melhor desempenho da Loja 3. Vale constar que a Loja 4 teve apenas 2 decimos a mais de diferenca da Loja 1, assim tendo seu desempenho parecido.
#
# *   Produtos Mais e Menos Vendidos: Foi identificado, por loja, quais produtos obtiveram maior e menor volume de vendas, fornecendo insights sobre o mix de produtos. Conferindo que:
#             Loja 1: Teve Micro-ondas, TV Led UHD 4K e Guarda roupas com maior numero de vendas por produto com 60 unidades cada, logo Headset e Celular ABXY com menor numero de vendas com 33 unidades cada.
#             Loja 2: Teve Iniciando em programação com maior numero de vendas por produto com 65 unidades cada, logo Jogo de tabuleiro com menor numero de vendas com 32 unidades cada.
#             Loja 3: Teve Kit banquetas com maior numero de vendas por produto com 57 unidades cada, logo Blocos de montar com menor numero de vendas com 35 unidades cada.
#             Loja 4: Teve Cama box com maior numero de vendas por produto com 62 unidades cada, logo Guitarra com menor numero de vendas com 33 unidades cada.
# Foi constatado que o produto Iniciando em programação teve maior numero de vendas e o produto Jogo de tabuleiro como menor numero de vendas, ambos tendo a Loja 2 como sua representante.
#
# *   Custo Médio com Frete: Também foi calculado o valor médio gasto com frete por cada loja, ajudando a entender o impacto logístico nos custos operacionais.
#             Loja 1: Media de R$ 34.69
#             Loja 2: Media de R$ 33.62
#             Loja 3: Media de R$ 33.07
#             Loja 4: Media de R$ 31.28
# Foi definido que a Loja 1 tem o custo medio maior em relacao as outras lojas e a Loja 4 como o menor custo.
#
# *   Faturamento Total (Produtos + Frete): Como extra, foi calculado o somatório dos valores de venda e do custo de frete para cada loja, para melhor analise e tomada de decisao:
#             Loja 1: R$ 1616347.09
#             Loja 2: R$ 1567773.22
#             Loja 3: R$ 1542047.69
#             Loja 4: R$ 1458253.46
# A Loja 1 teve maior faturamento total e a loja 4 o menor faturamento total.
#
# Com base em todos esses dados e gráficos gerados, é possível observar os pontos fortes e fracos de cada loja. A loja a ser escolhida para venda deve apresentar um equilíbrio entre alto faturamento, boa avaliação dos clientes, diversidade e boa performance de categorias e produtos, além de um frete com custo competitivo.
#
# Recomenda-se que o Senhor João considere a venda da Loja 4, pois teve menor combinação de desempenho, representacao de faturamento, mesmo tendo venda de produtos similiares com as outras lojas e o custo menor de frete. Suas vendas foram maiores em relacao a  produtos que o preco sao inferiores, nisso ha um impacto no valor total do faturamento. Aconselho tambem a busca por melhoria da Loja 1, pois tem o custo medio maior em relacao as outras, porem melhor faturamento.
